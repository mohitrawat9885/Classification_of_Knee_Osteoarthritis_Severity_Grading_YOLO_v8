# %%
# !pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ML_Projects/Classification_of_Knee_Severity_Grade
# !ls
# Out:
# /content/drive/MyDrive/ML_Projects/Classification_of_Knee_Severity_Grade
# Classification_of_Knee_Severity_Grade.ipynb  runs	     yolov8n.pt
# datasets				     test_images
# dataset.yaml				     yolov8n-cls.pt

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.83 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %%
from ultralytics import YOLO

model = YOLO('yolov8n-cls.pt')  # load a pretrained model (recommended for training)
# Train the model

model.train(data='MedicalExpert', epochs=100, batch=16, optimizer='Adam',  lr0=0.001, imgsz=224, name="train_india")

# !yolo task=classify mode=train data=kneeKL299 model=yolov8n-cls.pt epochs=2 batch=8 project=training_results name=knee
# Out:
# Ultralytics YOLOv8.0.83 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=classify mode=predict model=runs/classify/train/weights/best.pt line_thickness=1 conf=0.55 source=test_images save=True
